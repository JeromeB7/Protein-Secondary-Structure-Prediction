# %%
import torch
from transformers import AutoTokenizer, AutoModel
import pandas as pd
import csv
import json

# Load ProtBERT tokenizer and model
tokenizer = AutoTokenizer.from_pretrained("Rostlab/prot_bert")
model = AutoModel.from_pretrained("Rostlab/prot_bert")
model.eval()

# Function to get token embeddings
def get_embeddings(sequence):
    sequence = " ".join(sequence)  # Add spaces between amino acids
    inputs = tokenizer(sequence, return_tensors="pt", padding=True, truncation=True)
    with torch.no_grad():
        outputs = model(**inputs)
    return outputs.last_hidden_state.squeeze().tolist()

# Load dataset
csv_file = "Train.csv"  # Update the path if needed
df = pd.read_csv(csv_file)
sequences = df['Sequence'].tolist()

# Output CSV file
output_file = "/content/drive/MyDrive/PSSP big/train_embeddings_2"
start_idx = 1000  # Start from 1001st sequence (index 1000)
end_idx = 2000  # Stop at 2000th sequence (index 1999)

# Write embeddings to CSV with checkpointing
with open(output_file, mode="w", newline="") as f:
    writer = csv.writer(f)
    writer.writerow(["sequence", "embedding"])  # CSV header

    for i, seq in enumerate(sequences[start_idx:end_idx], start=start_idx + 1):
        embeddings = get_embeddings(seq)
        print(f"Processed {i}: {seq[:10]}... -> {len(embeddings)} embeddings")  # Output progress
        writer.writerow([seq, json.dumps(embeddings)])  # Save to CSV

print(f"Processed sequences {start_idx + 1} to {end_idx}. Embeddings saved to {output_file}")
# Out:
# /usr/local/lib/python3.11/dist-packages/huggingface_hub/utils/_auth.py:94: UserWarning:
# The secret `HF_TOKEN` does not exist in your Colab secrets.
# To authenticate with the Hugging Face Hub, create a token in your settings tab (https://huggingface.co/settings/tokens), set it as secret in your Google Colab and restart your session.
# You will be able to reuse this secret in all of your notebooks.
# Please note that authentication is recommended but still optional to access public models or datasets.
#   warnings.warn(
# tokenizer_config.json:   0%|          | 0.00/86.0 [00:00<?, ?B/s]
# config.json:   0%|          | 0.00/361 [00:00<?, ?B/s]
# vocab.txt:   0%|          | 0.00/81.0 [00:00<?, ?B/s]
# special_tokens_map.json:   0%|          | 0.00/112 [00:00<?, ?B/s]
# pytorch_model.bin:   0%|          | 0.00/1.68G [00:00<?, ?B/s]
# model.safetensors:   0%|          | 0.00/1.68G [00:00<?, ?B/s]
# Asking to truncate to max_length but no maximum length is provided and the model has no predefined maximum length. Default to no truncation.
# Processed 1001: MAASNATYNN... -> 119 embeddings
# Processed 1002: MSITLSDSAA... -> 109 embeddings
# Processed 1003: MEHICGTSRI... -> 202 embeddings
# Processed 1004: MSVFDSKFKG... -> 412 embeddings
# Processed 1005: SDAATTFLQR... -> 209 embeddings
# Processed 1006: MRTELLSKLY... -> 264 embeddings
# Processed 1007: MPELEVKGKK... -> 117 embeddings
# Processed 1008: AFRILTINPG... -> 383 embeddings
# Processed 1009: GSHAFAPSDR... -> 108 embeddings
# Processed 1010: MDLTNKNVIF... -> 256 embeddings
# Processed 1011: MKKTQTWILT... -> 275 embeddings
# Processed 1012: ATNKQVEISA... -> 128 embeddings
# Processed 1013: GAKNYYDITL... -> 215 embeddings
# Processed 1014: AARGANHVYL... -> 303 embeddings
# Processed 1015: GHMDSMDHRI... -> 119 embeddings
# Processed 1016: MSLMGYKNNR... -> 276 embeddings
# Processed 1017: MGGSHHHHHH... -> 166 embeddings
# Processed 1018: MDWLPRNTNC... -> 116 embeddings
# Processed 1019: MHHHHHHSSG... -> 242 embeddings
# Processed 1020: MDLLSCTVND... -> 77 embeddings
# Processed 1021: GSQRVLVEPD... -> 262 embeddings
# Processed 1022: MSNPTKISIL... -> 395 embeddings
# Processed 1023: MTSRGDSREK... -> 193 embeddings
# Processed 1024: GHMPLPTELA... -> 156 embeddings
# Processed 1025: GSCRRAFDLY... -> 184 embeddings
# Processed 1026: MSRQTEIVRR... -> 146 embeddings
# Processed 1027: GSHMLEQKKA... -> 98 embeddings
# Processed 1028: AYRIASYDFA... -> 25 embeddings
# Processed 1029: ANPHKDVLKG... -> 445 embeddings
# Processed 1030: MSKVFIATAN... -> 399 embeddings
# Processed 1031: MSSDKNGDIL... -> 314 embeddings
# Processed 1032: ANKIFIYAGV... -> 244 embeddings
# Processed 1033: MRPLTEEETR... -> 190 embeddings
# Processed 1034: ESNPDPTTYP... -> 168 embeddings
# Processed 1035: MLIDPIELYR... -> 300 embeddings
# Processed 1036: SNAAAKNKLL... -> 155 embeddings
# Processed 1037: MRRLNRKNNE... -> 340 embeddings
# Processed 1038: MHHHHHHSSG... -> 210 embeddings
# Processed 1039: MNRLLNEKVE... -> 237 embeddings
# Processed 1040: TAAVALVKAN... -> 66 embeddings
# Processed 1041: GLKEHDFNPE... -> 379 embeddings
# Processed 1042: NDDINKGPSG... -> 329 embeddings
# Processed 1043: SLRSDLINAL... -> 246 embeddings
# Processed 1044: AEEELETPTP... -> 88 embeddings
# Processed 1045: MSHHHHHHGS... -> 202 embeddings
# Processed 1046: GSSSTLTKEL... -> 163 embeddings
# Processed 1047: AHHHHHHGST... -> 381 embeddings
# Processed 1048: GRPLLQAAKG... -> 26 embeddings
# Processed 1049: GHASRTVACR... -> 96 embeddings
# Processed 1050: AELATRAIPE... -> 521 embeddings
# Processed 1051: SNAMTTPIRV... -> 254 embeddings
# Processed 1052: GSAMAKANSS... -> 278 embeddings
# Processed 1053: MKVGIIMGSV... -> 193 embeddings
# Processed 1054: QEFLLRVEPQ... -> 88 embeddings
# Processed 1055: NLYFQGHMRK... -> 127 embeddings
# Processed 1056: PILEKAPQKM... -> 641 embeddings
# Processed 1057: MNIPTTTTKG... -> 226 embeddings
# Processed 1058: ATKIDKEACR... -> 143 embeddings
# Processed 1059: AYKVKVYVSL... -> 86 embeddings
# Processed 1060: EKWMEIDVLK... -> 198 embeddings
# Processed 1061: SVDHGFLVTR... -> 231 embeddings
# Processed 1062: AANTDLKLPA... -> 128 embeddings
# Processed 1063: GSHMSLDNKP... -> 317 embeddings
# Processed 1064: MDRKTRLSEP... -> 292 embeddings
# Processed 1065: MQEQRQQLLR... -> 164 embeddings
# Processed 1066: MTKEPRNLSE... -> 120 embeddings
# Processed 1067: HCDLPCGVYD... -> 119 embeddings
# Processed 1068: GPVSLSTPAQ... -> 416 embeddings
# Processed 1069: AGHHHHHHSH... -> 157 embeddings
# Processed 1070: MGNKEKADRQ... -> 118 embeddings
# Processed 1071: MNTKYNKEFL... -> 165 embeddings
# Processed 1072: PKDAQVIMSI... -> 70 embeddings
# Processed 1073: MLYGSSISAE... -> 72 embeddings
# Processed 1074: MGSSHHHHHH... -> 349 embeddings
# Processed 1075: MAHHHHHHMT... -> 196 embeddings
# Processed 1076: MCELLGMSAN... -> 259 embeddings
# Processed 1077: MGFKLVGFSK... -> 426 embeddings
# Processed 1078: MSEPEVPFKV... -> 70 embeddings
# Processed 1079: GAMNFLAETA... -> 83 embeddings
# Processed 1080: ASSDTTCASL... -> 55 embeddings
# Processed 1081: MSVKAKKCSR... -> 182 embeddings
# Processed 1082: MQEGQNRKTS... -> 153 embeddings
# Processed 1083: MPVITLPDGS... -> 226 embeddings
# Processed 1084: APDIPLANVK... -> 286 embeddings
# Processed 1085: MTCAYRREIH... -> 130 embeddings
# Processed 1086: AIYLRKANER... -> 244 embeddings
# Processed 1087: GSHMEYLGVF... -> 107 embeddings
# Processed 1088: MDYKDDDDKS... -> 417 embeddings
# Processed 1089: ARGRLQGVEL... -> 104 embeddings
# Processed 1090: SHPALTQLRA... -> 166 embeddings
# Processed 1091: GHMTLYRLHE... -> 150 embeddings
# Processed 1092: REEGGVGSEE... -> 748 embeddings
# Processed 1093: GHMNAADRVM... -> 136 embeddings
# Processed 1094: AMKPRIYVKV... -> 193 embeddings
# Processed 1095: GSEFGSGSNM... -> 214 embeddings
# Processed 1096: MHHHHHHMGI... -> 158 embeddings
# Processed 1097: MLTVIAEIRT... -> 116 embeddings
# Processed 1098: MAYRALMVLR... -> 111 embeddings
# Processed 1099: MVEQIKDKLG... -> 342 embeddings
# Processed 1100: GPHTSSYAQA... -> 371 embeddings
# Processed 1101: MGHHHHHHSH... -> 155 embeddings
# Processed 1102: MALLEICCYS... -> 258 embeddings
# Processed 1103: MSDLANSEKY... -> 1226 embeddings
# Processed 1104: MSDYEEAFND... -> 157 embeddings
# Processed 1105: MSNTLFDDIF... -> 148 embeddings
# Processed 1106: MTTFRFCRDC... -> 124 embeddings
# Processed 1107: MNAPDRFELF... -> 122 embeddings
# Processed 1108: MSREGFQIPT... -> 72 embeddings
# Processed 1109: MGKRFSSFQA... -> 141 embeddings
# Processed 1110: MIVSILGAGA... -> 337 embeddings
# Processed 1111: MFSIDDVAKQ... -> 500 embeddings
# Processed 1112: DSSQFADDSG... -> 59 embeddings
# Processed 1113: MASKAVILAG... -> 261 embeddings
# Processed 1114: ATPWQKITQP... -> 257 embeddings
# Processed 1115: ASLIFLDYDG... -> 241 embeddings
# Processed 1116: ASGPRALSRN... -> 92 embeddings
# Processed 1117: GSHGGSGFMA... -> 384 embeddings
# Processed 1118: GFKTFYIKVI... -> 88 embeddings
# Processed 1119: AAHQVISATT... -> 174 embeddings
# Processed 1120: AMNGTEGPNF... -> 351 embeddings
# Processed 1121: GSKAPPTFKV... -> 101 embeddings
# Processed 1122: GAADKIAIVN... -> 145 embeddings
# Processed 1123: MKKKDTCEIF... -> 124 embeddings
# Processed 1124: MGHHHHHHKK... -> 436 embeddings
# Processed 1125: RASVGSPGIP... -> 150 embeddings
# Processed 1126: MRSRTANRSG... -> 246 embeddings
# Processed 1127: MTWKNFGFEI... -> 376 embeddings
# Processed 1128: MLDANKLQQA... -> 312 embeddings
# Processed 1129: VIRVYIASSS... -> 123 embeddings
# Processed 1130: MFEARLVQGS... -> 263 embeddings
# Processed 1131: APAVADKADN... -> 387 embeddings
# Processed 1132: GHASARVRPF... -> 138 embeddings
# Processed 1133: MATALYTAND... -> 394 embeddings
# Processed 1134: MTRLPKLAVF... -> 166 embeddings
# Processed 1135: SPVNDLKHLN... -> 228 embeddings
# Processed 1136: SNAMDGQQLN... -> 92 embeddings
# Processed 1137: MSLTQHLVIT... -> 194 embeddings
# Processed 1138: MLMTAEQYIE... -> 492 embeddings
# Processed 1139: AHHHHHHSSG... -> 474 embeddings
# Processed 1140: AIVLEEERYD... -> 116 embeddings
# Processed 1141: AHAAIDTFTK... -> 72 embeddings
# Processed 1142: MKGMSKMPQF... -> 122 embeddings
# Processed 1143: MPTWEELYKN... -> 457 embeddings
# Processed 1144: PSIKSGTILH... -> 424 embeddings
# Processed 1145: MSRSRQPPLV... -> 101 embeddings
# Processed 1146: MEELKEIMKS... -> 102 embeddings
# Processed 1147: FDSFWFVQQW... -> 192 embeddings
# Processed 1148: AHIVYDDVRD... -> 247 embeddings
# Processed 1149: MISVTDLRPG... -> 186 embeddings
# Processed 1150: MERLAPAKVN... -> 277 embeddings
# Processed 1151: TRQMILAVGQ... -> 305 embeddings
# Processed 1152: MHHHHHHSSG... -> 182 embeddings
# Processed 1153: GSHMPVPSFG... -> 66 embeddings
# Processed 1154: ARVRTERLTL... -> 240 embeddings
# Processed 1155: MTNLSDIIEK... -> 86 embeddings
# Processed 1156: AANDNNVEWN... -> 639 embeddings
# Processed 1157: MIKVRVPDFS... -> 502 embeddings
# Processed 1158: MTLELLQAQA... -> 207 embeddings
# Processed 1159: MARQLRAEQT... -> 217 embeddings
# Processed 1160: PGMAGDSEQT... -> 254 embeddings
# Processed 1161: MRGSHHHHHH... -> 79 embeddings
# Processed 1162: MQVFIMRHGD... -> 163 embeddings
# Processed 1163: SLSDFSVASR... -> 190 embeddings
# Processed 1164: APVRKAKAVW... -> 144 embeddings
# Processed 1165: HHHHHHVGVE... -> 117 embeddings
# Processed 1166: ASMSDVAIVK... -> 127 embeddings
# Processed 1167: DTCGSGYNVD... -> 66 embeddings
# Processed 1168: APFPFGKSHK... -> 343 embeddings
# Processed 1169: MFVFMLLLLL... -> 422 embeddings
# Processed 1170: AGEPTEFEYL... -> 62 embeddings
# Processed 1171: GSHGGIEGVK... -> 65 embeddings
# Processed 1172: MASRILLNNG... -> 318 embeddings
# Processed 1173: MRKPILAALT... -> 316 embeddings
# Processed 1174: MRSYRAQGPL... -> 180 embeddings
# Processed 1175: DDIKVAVVGA... -> 348 embeddings
# Processed 1176: MDWEERENLK... -> 82 embeddings
# Processed 1177: MRGSHHHHHH... -> 172 embeddings
# Processed 1178: GSHMGIQETD... -> 173 embeddings
# Processed 1179: MEQKQRRFTK... -> 189 embeddings
# Processed 1180: GAAVLSQRQR... -> 90 embeddings
# Processed 1181: GLDNELSLVD... -> 186 embeddings
# Processed 1182: VPGPEYKVAI... -> 169 embeddings
# Processed 1183: ASENANDIVT... -> 112 embeddings
# Processed 1184: PRRAPAFPLS... -> 666 embeddings
# Processed 1185: EGRDSMNLPS... -> 35 embeddings
# Processed 1186: LSKVVIRRLP... -> 93 embeddings
# Processed 1187: RPPLQEYVRK... -> 250 embeddings
# Processed 1188: ASTQGISEDL... -> 263 embeddings
# Processed 1189: MTDNNKYRDV... -> 559 embeddings
# Processed 1190: KYPRPHKKLK... -> 413 embeddings
# Processed 1191: APLVHHHHHH... -> 352 embeddings
# Processed 1192: GRGTKQVYII... -> 194 embeddings
# Processed 1193: GSMPVVWPTL... -> 104 embeddings
# Processed 1194: AMGSDASKVV... -> 98 embeddings
# Processed 1195: AASAVGEKAL... -> 180 embeddings
# Processed 1196: ADSATPHLDA... -> 508 embeddings
# Processed 1197: LPDADTLLHF... -> 49 embeddings
# Processed 1198: MRERTEARRR... -> 196 embeddings
# Processed 1199: MGSSHHHHHH... -> 368 embeddings
# Processed 1200: AKPLSSPLQQ... -> 442 embeddings
# Processed 1201: MTKNKLNQNS... -> 301 embeddings
# Processed 1202: MYSIEVRTHS... -> 159 embeddings
# Processed 1203: MIQMVKRVHI... -> 403 embeddings
# Processed 1204: LECHNQQSSQ... -> 64 embeddings
# Processed 1205: MRVDLNSDLG... -> 257 embeddings
# Processed 1206: MEIKDLKRLA... -> 107 embeddings
# Processed 1207: NGETSRPPAL... -> 358 embeddings
# Processed 1208: LNDPLDSGRF... -> 109 embeddings
# Processed 1209: MNKMAMIDLA... -> 89 embeddings
# Processed 1210: MVGGGGVKFI... -> 214 embeddings
# Processed 1211: MKYGYFDNDN... -> 809 embeddings
# Processed 1212: MSKSVFVGEL... -> 262 embeddings
# Processed 1213: ALPTIHVVTP... -> 255 embeddings
# Processed 1214: MRRGSGNPER... -> 237 embeddings
# Processed 1215: PFRTIARLNP... -> 109 embeddings
# Processed 1216: MPLPPDITFD... -> 151 embeddings
# Processed 1217: AQRVQLTATV... -> 327 embeddings
# Processed 1218: MADDFAYLNA... -> 325 embeddings
# Processed 1219: MGSSHHHHHH... -> 169 embeddings
# Processed 1220: AVFKIKDEWG... -> 216 embeddings
# Processed 1221: MNVVIVRYGE... -> 309 embeddings
# Processed 1222: METYPITVGG... -> 177 embeddings
# Processed 1223: MEEVEEFKYE... -> 207 embeddings
# Processed 1224: MTAFRQRPLR... -> 226 embeddings
# Processed 1225: MSVKTWRKIA... -> 256 embeddings
# Processed 1226: MRGKVYLVGA... -> 237 embeddings
# Processed 1227: MRRFALTVAL... -> 208 embeddings
# Processed 1228: AESSGKSEAP... -> 371 embeddings
# Processed 1229: MADNLPSDFD... -> 652 embeddings
# Processed 1230: ARAFIAIDVN... -> 186 embeddings
# Processed 1231: MSLKRKNIAL... -> 233 embeddings
# Processed 1232: SLMAGLPNSS... -> 437 embeddings
# Processed 1233: MSLIWKRKIT... -> 150 embeddings
# Processed 1234: ASLAIQNPYT... -> 147 embeddings
# Processed 1235: ASLEVKVGLA... -> 320 embeddings
# Processed 1236: ASLITAKKIG... -> 234 embeddings
# Processed 1237: MSLRYIVALT... -> 220 embeddings
# Processed 1238: MSLSKSLQKP... -> 200 embeddings
# Processed 1239: ASLKQKRPKY... -> 208 embeddings
# Processed 1240: ASLARDITPD... -> 176 embeddings
# Processed 1241: MSLEKEYEYL... -> 210 embeddings
# Processed 1242: MGHHHHHHGG... -> 202 embeddings
# Processed 1243: MGSDKIHHHH... -> 220 embeddings
# Processed 1244: MGSDKIHHHH... -> 166 embeddings
# Processed 1245: KTIFVIVPTN... -> 81 embeddings
# Processed 1246: AAHHHHHHAS... -> 311 embeddings
# Processed 1247: AGSDKIHHHH... -> 417 embeddings
# Processed 1248: MGSDKIHHHH... -> 159 embeddings
# Processed 1249: MGVEKVPKYD... -> 244 embeddings
# Processed 1250: MGSDKIHHHH... -> 617 embeddings
# Processed 1251: MGSDKIHHHH... -> 300 embeddings
# Processed 1252: MGSDKIHHHH... -> 271 embeddings
# Processed 1253: MGSDKIHHHH... -> 135 embeddings
# Processed 1254: MGSDKIHHHH... -> 190 embeddings
# Processed 1255: MGSDKIHHHH... -> 275 embeddings
# Processed 1256: MGSDKIHHHH... -> 183 embeddings
# Processed 1257: MGSDKIHHHH... -> 156 embeddings
# Processed 1258: AGSDKIHHHH... -> 220 embeddings
# Processed 1259: MGSDKIHHHH... -> 349 embeddings
# Processed 1260: MGSDKIHHHH... -> 234 embeddings
# Processed 1261: MGSDKIHHHH... -> 449 embeddings
# Processed 1262: AGSDKIHHHH... -> 262 embeddings
# Processed 1263: MGSDKIHHHH... -> 159 embeddings
# Processed 1264: AGSDKIHHHH... -> 221 embeddings
# Processed 1265: AGSDKIHHHH... -> 340 embeddings
# Processed 1266: MGSDKIHHHH... -> 142 embeddings
# Processed 1267: MGSDKIHHHH... -> 97 embeddings
# Processed 1268: MGSDKIHHHH... -> 146 embeddings
# Processed 1269: AGSDKIHHHH... -> 102 embeddings
# Processed 1270: AGSDKIHHHH... -> 203 embeddings
# Processed 1271: MGSDKIHHHH... -> 453 embeddings
# Processed 1272: AGSDKIHHHH... -> 171 embeddings
# Processed 1273: MGSDKIHHHH... -> 275 embeddings
# Processed 1274: VCEKGFEAGD... -> 376 embeddings
# Processed 1275: MTGAGTPSQG... -> 59 embeddings
# Processed 1276: MGKKSKATKK... -> 52 embeddings
# Processed 1277: MQMPRRFNTY... -> 94 embeddings
# Processed 1278: MPQPSRPRKG... -> 340 embeddings
# Processed 1279: MPRVELEIPE... -> 180 embeddings
# Processed 1280: KPASMYRDID... -> 173 embeddings
# Processed 1281: MARSAYSYIR... -> 197 embeddings
# Processed 1282: MSKTNPRLSS... -> 118 embeddings
# Processed 1283: MTDLSAQKRL... -> 151 embeddings
# Processed 1284: MPSSNGPLEG... -> 98 embeddings
# Processed 1285: MGISYSVEAD... -> 157 embeddings
# Processed 1286: PRTRECDYCG... -> 68 embeddings
# Processed 1287: MHALVQLRGE... -> 156 embeddings
# Processed 1288: MSASDFEERV... -> 94 embeddings
# Processed 1289: RSGRFGARYG... -> 85 embeddings
# Processed 1290: MASKDKEINN... -> 648 embeddings
# Processed 1291: AGSDKIHHHH... -> 299 embeddings
# Processed 1292: AGSDKIHHHH... -> 118 embeddings
# Processed 1293: AGSDKIHHHH... -> 193 embeddings
# Processed 1294: MIVTTTSGIQ... -> 105 embeddings
# Processed 1295: AGSDKIHHHH... -> 144 embeddings
# Processed 1296: AGSDKIHHHH... -> 144 embeddings
# Processed 1297: TALSFVTTDA... -> 217 embeddings
# Processed 1298: DTAIEKRLAS... -> 138 embeddings
# Processed 1299: MTGSNSHITI... -> 240 embeddings
# Processed 1300: WSATNEEDDL... -> 114 embeddings
# Processed 1301: EARPIVVGPP... -> 151 embeddings
# Processed 1302: MSRKPSGLGR... -> 232 embeddings
# Processed 1303: AAKELTLAQT... -> 47 embeddings
# Processed 1304: MDYLVKALAY... -> 293 embeddings
# Processed 1305: MEGIDHLADE... -> 661 embeddings
# Processed 1306: GSHAADSYYD... -> 206 embeddings
# Processed 1307: WQFTPNTGGN... -> 133 embeddings
# Processed 1308: MRFKNVKKTA... -> 783 embeddings
# Processed 1309: GPLGSNIEQY... -> 153 embeddings
# Processed 1310: VKQVFNFNAG... -> 362 embeddings
# Processed 1311: ASWVQLAGHT... -> 278 embeddings
# Processed 1312: ASLEAIVFDR... -> 213 embeddings
# Processed 1313: CPRAGHVFPL... -> 193 embeddings
# Processed 1314: HMSSGSAGLS... -> 176 embeddings
# Processed 1315: MDFREVIEQR... -> 86 embeddings
# Processed 1316: MSFTPANRAY... -> 339 embeddings
# Processed 1317: ESHMAMDLGG... -> 280 embeddings
# Processed 1318: GAMAGSIRSK... -> 234 embeddings
# Processed 1319: MTEGTCLRRR... -> 734 embeddings
# Processed 1320: NDKLVELSKS... -> 601 embeddings
# Processed 1321: YDGTKCKAAG... -> 76 embeddings
# Processed 1322: ASAECVSNEN... -> 749 embeddings
# Processed 1323: AAALIDTGIF... -> 158 embeddings
# Processed 1324: MANLTEKFLR... -> 265 embeddings
# Processed 1325: IIAPSRGSPL... -> 285 embeddings
# Processed 1326: MSDLETVAKF... -> 962 embeddings
# Processed 1327: MASDKFPVAE... -> 299 embeddings
# Processed 1328: MSAIENFDAH... -> 802 embeddings
# Processed 1329: AMKNWKTSAE... -> 216 embeddings
# Processed 1330: NQKCSGNPRR... -> 183 embeddings
# Processed 1331: MLRAKVRRIA... -> 259 embeddings
# Processed 1332: MRRLEEDAVR... -> 263 embeddings
# Processed 1333: MGPCDIYEAG... -> 484 embeddings
# Processed 1334: ARFRDRRHAG... -> 210 embeddings
# Processed 1335: MSPQTETKAS... -> 479 embeddings
# Processed 1336: MPLVLDLARP... -> 189 embeddings
# Processed 1337: ARLLAVFVSS... -> 173 embeddings
# Processed 1338: MEKIMPEEEY... -> 336 embeddings
# Processed 1339: DTASDAAAAA... -> 40 embeddings
# Processed 1340: ARDLDREETY... -> 292 embeddings
# Processed 1341: APVLENRRAR... -> 124 embeddings
# Processed 1342: ATKAELRRRA... -> 186 embeddings
# Processed 1343: MHHHHHHAMN... -> 166 embeddings
# Processed 1344: AAGSVPATNQ... -> 342 embeddings
# Processed 1345: MGHHHHHHSS... -> 503 embeddings
# Processed 1346: SSDRLAGAGS... -> 181 embeddings
# Processed 1347: GLDVAISQNG... -> 301 embeddings
# Processed 1348: MAGSREVVAM... -> 191 embeddings
# Processed 1349: MRDPFMEALG... -> 138 embeddings
# Processed 1350: GPHMATADRD... -> 107 embeddings
# Processed 1351: MEQLRGLYPP... -> 319 embeddings
# Processed 1352: GPLGSQVRVK... -> 91 embeddings
# Processed 1353: GPHMSIVEVK... -> 88 embeddings
# Processed 1354: MTYRVKIHKQ... -> 92 embeddings
# Processed 1355: MRMEKVGDVL... -> 69 embeddings
# Processed 1356: APEGYRKLLD... -> 207 embeddings
# Processed 1357: MIKMFKYKQV... -> 123 embeddings
# Processed 1358: AVRVGARAAP... -> 133 embeddings
# Processed 1359: TNRLVLSGTV... -> 105 embeddings
# Processed 1360: MKRVEDWIKQ... -> 124 embeddings
# Processed 1361: MARYEEVSVS... -> 125 embeddings
# Processed 1362: GHMIQESTME... -> 174 embeddings
# Processed 1363: MEKILIFGHQ... -> 190 embeddings
# Processed 1364: TLHKERRIGR... -> 149 embeddings
# Processed 1365: AAATRQEEAI... -> 74 embeddings
# Processed 1366: MTSADLTKPI... -> 188 embeddings
# Processed 1367: MATVHKVGDS... -> 111 embeddings
# Processed 1368: GAMAEAEAEV... -> 83 embeddings
# Processed 1369: MNKQEVILKV... -> 274 embeddings
# Processed 1370: MSASHADQPT... -> 345 embeddings
# Processed 1371: MSPGPQSGGQ... -> 222 embeddings
# Processed 1372: AHKLIIKYNK... -> 240 embeddings
# Processed 1373: ARKVRPEELP... -> 96 embeddings
# Processed 1374: SEQNNAVLPK... -> 522 embeddings
# Processed 1375: SIDKNFWQGK... -> 361 embeddings
# Processed 1376: MTDMSIKFEL... -> 169 embeddings
# Processed 1377: VALTVYYPPR... -> 120 embeddings
# Processed 1378: ALAKVAEFER... -> 150 embeddings
# Processed 1379: AAEKALATLK... -> 121 embeddings
# Processed 1380: MDEIKIEKLK... -> 161 embeddings
# Processed 1381: LSDEDFKAVF... -> 37 embeddings
# Processed 1382: MNPESRVIRK... -> 319 embeddings
# Processed 1383: TIVKSEIIRK... -> 174 embeddings
# Processed 1384: AETALYLLPV... -> 244 embeddings
# Processed 1385: GPMATESPNS... -> 98 embeddings
# Processed 1386: MTTATAGLAV... -> 217 embeddings
# Processed 1387: MYELYTLLAE... -> 254 embeddings
# Processed 1388: MVDIVKRRDW... -> 122 embeddings
# Processed 1389: MIAMDIREIG... -> 442 embeddings
# Processed 1390: MIEKVYCQEV... -> 436 embeddings
# Processed 1391: GSHMDINNKA... -> 93 embeddings
# Processed 1392: GHMVDTSGVK... -> 198 embeddings
# Processed 1393: MAHHHHHHMS... -> 176 embeddings
# Processed 1394: ALEGTEFARS... -> 125 embeddings
# Processed 1395: GPLGSKISKR... -> 100 embeddings
# Processed 1396: MTYFIDVPTA... -> 352 embeddings
# Processed 1397: MIRKAFVMQV... -> 106 embeddings
# Processed 1398: ACTKNAIAQT... -> 186 embeddings
# Processed 1399: GAMDSSEMST... -> 155 embeddings
# Processed 1400: MSQLLQDYLN... -> 304 embeddings
# Processed 1401: MIVSDIEANA... -> 700 embeddings
# Processed 1402: GSHMSQSFGR... -> 190 embeddings
# Processed 1403: SCELYHYQEC... -> 85 embeddings
# Processed 1404: MEKATKRNDE... -> 124 embeddings
# Processed 1405: AKGRAGRSKR... -> 142 embeddings
# Processed 1406: GSHMAVYVKF... -> 122 embeddings
# Processed 1407: GSACAEFSFH... -> 318 embeddings
# Processed 1408: MEGQRWLPLE... -> 232 embeddings
# Processed 1409: GHMDQSDFSP... -> 279 embeddings
# Processed 1410: GQEKLYIEKE... -> 689 embeddings
# Processed 1411: DLLSWFKGND... -> 300 embeddings
# Processed 1412: AHHHHHHGSG... -> 118 embeddings
# Processed 1413: MSANVQEAAN... -> 205 embeddings
# Processed 1414: CGIVGAIAQR... -> 242 embeddings
# Processed 1415: MNPNFTTEHT... -> 338 embeddings
# Processed 1416: MSTTPIDAEL... -> 180 embeddings
# Processed 1417: AMDASAKAPQ... -> 78 embeddings
# Processed 1418: ANLYFQSNAV... -> 113 embeddings
# Processed 1419: MAQQKKTIAV... -> 354 embeddings
# Processed 1420: SNAAIYPYKE... -> 175 embeddings
# Processed 1421: AGSSHHHHHH... -> 186 embeddings
# Processed 1422: GASSLKDEVP... -> 390 embeddings
# Processed 1423: MDGNEEMGGI... -> 107 embeddings
# Processed 1424: MKIPIEELED... -> 81 embeddings
# Processed 1425: RTNQAGLELI... -> 165 embeddings
# Processed 1426: ATNYIYTPLN... -> 296 embeddings
# Processed 1427: HYANQLMLSE... -> 206 embeddings
# Processed 1428: GSHADHLPAP... -> 410 embeddings
# Processed 1429: ASDEEIQDVS... -> 164 embeddings
# Processed 1430: AQFRGESVQI... -> 248 embeddings
# Processed 1431: MSWIEPIISH... -> 126 embeddings
# Processed 1432: MQNLLANLAA... -> 145 embeddings
# Processed 1433: HMKISERQKD... -> 208 embeddings
# Processed 1434: GSMFPHHSIT... -> 452 embeddings
# Processed 1435: ESTSATQPPG... -> 667 embeddings
# Processed 1436: MAYDLSEFMG... -> 94 embeddings
# Processed 1437: SKVVYVSHDG... -> 108 embeddings
# Processed 1438: MSALTIGGKS... -> 266 embeddings
# Processed 1439: NAMMYFISDT... -> 197 embeddings
# Processed 1440: GSHMASLDMA... -> 81 embeddings
# Processed 1441: SATEPPKIVW... -> 105 embeddings
# Processed 1442: NAMAIHVGII... -> 387 embeddings
# Processed 1443: SNTSWRKSEV... -> 277 embeddings
# Processed 1444: SDEVRKNLMD... -> 326 embeddings
# Processed 1445: SKELLAEYQD... -> 185 embeddings
# Processed 1446: ASWSHPQFEK... -> 328 embeddings
# Processed 1447: MKKLIVDLDG... -> 128 embeddings
# Processed 1448: GHMQRERTAE... -> 117 embeddings
# Processed 1449: MAAESQLKRV... -> 258 embeddings
# Processed 1450: GSSHHHHHHS... -> 298 embeddings
# Processed 1451: SNAAKETVTA... -> 511 embeddings
# Processed 1452: MAKLTSAVPV... -> 126 embeddings
# Processed 1453: GSAMDVRQSI... -> 284 embeddings
# Processed 1454: AKTIEVDDEL... -> 52 embeddings
# Processed 1455: QDDLTISSLA... -> 138 embeddings
# Processed 1456: GSHMGQNDLV... -> 115 embeddings
# Processed 1457: GASHPEIEKA... -> 358 embeddings
# Processed 1458: MDYKESCPSV... -> 156 embeddings
# Processed 1459: MPLYVIDKPI... -> 218 embeddings
# Processed 1460: MKHQHQHQHQ... -> 288 embeddings
# Processed 1461: MGSSHHHHHH... -> 300 embeddings
# Processed 1462: SMRICIFMAR... -> 403 embeddings
# Processed 1463: GPHMSIHSGR... -> 112 embeddings
# Processed 1464: DQVDVKDCAN... -> 131 embeddings
# Processed 1465: MGSSHHHHHH... -> 152 embeddings
# Processed 1466: MASMTGGQQM... -> 248 embeddings
# Processed 1467: MQAYSNPGYS... -> 122 embeddings
# Processed 1468: MGSSHHHHHH... -> 325 embeddings
# Processed 1469: GMTSPVAVIA... -> 104 embeddings
# Processed 1470: ANEADYLRLL... -> 211 embeddings
# Processed 1471: GHMLIPHDLL... -> 80 embeddings
# Processed 1472: LKQINHQGEE... -> 189 embeddings
# Processed 1473: AKIDNAVLPE... -> 344 embeddings
# Processed 1474: MAHHHHHHMP... -> 193 embeddings
# Processed 1475: MKTLCTHSLP... -> 339 embeddings
# Processed 1476: QSEEYCASAW... -> 175 embeddings
# Processed 1477: GIDPFTATTA... -> 135 embeddings
# Processed 1478: AKITKVQVGE... -> 171 embeddings
# Processed 1479: GPGSMEQPKG... -> 186 embeddings
# Processed 1480: MKQWSEEVER... -> 54 embeddings
# Processed 1481: MQQSLAVKTF... -> 95 embeddings
# Processed 1482: GHQLPIWKQD... -> 265 embeddings
# Processed 1483: SNAARETFEI... -> 132 embeddings
# Processed 1484: GHMLRGLRII... -> 225 embeddings
# Processed 1485: AVKVTYDIPT... -> 135 embeddings
# Processed 1486: MGSSHHHHHH... -> 201 embeddings
# Processed 1487: MGSSHHHHHH... -> 334 embeddings
# Processed 1488: GSSQLPQNIQ... -> 100 embeddings
# Processed 1489: MSEWMKKGPL... -> 88 embeddings
# Processed 1490: AQESLESQEQ... -> 87 embeddings
# Processed 1491: ASLVEKQSAL... -> 180 embeddings
# Processed 1492: SSSNSEKEWH... -> 117 embeddings
# Processed 1493: MYMKHIENGT... -> 142 embeddings
# Processed 1494: MATSELSSEV... -> 92 embeddings
# Processed 1495: MTKPYVRLDK... -> 210 embeddings
# Processed 1496: HHHHHHSSGL... -> 223 embeddings
# Processed 1497: MHHHHHHPPK... -> 239 embeddings
# Processed 1498: MGSSHHHHHH... -> 277 embeddings
# Processed 1499: MWEANELSST... -> 444 embeddings
# Processed 1500: MTVQIPKLLF... -> 245 embeddings
# Processed 1501: AHHHHHHGSN... -> 397 embeddings
# Processed 1502: GPLGSGFTVL... -> 195 embeddings
# Processed 1503: VGWEQLLTTI... -> 26 embeddings
# Processed 1504: AGHHHHHHHH... -> 408 embeddings
# Processed 1505: MKLTLKNLSM... -> 358 embeddings
# Processed 1506: AKIIITGEPG... -> 180 embeddings
# Processed 1507: MFYKEENFKK... -> 427 embeddings
# Processed 1508: MLGAIAYTGN... -> 261 embeddings
# Processed 1509: MQIVQIEQAP... -> 344 embeddings
# Processed 1510: GASIVPLYKL... -> 332 embeddings
# Processed 1511: MDDSREESQF... -> 113 embeddings
# Processed 1512: NCCVKGNSIY... -> 369 embeddings
# Processed 1513: CLGTIGPVTP... -> 311 embeddings
# Processed 1514: MFLVDSHCHL... -> 267 embeddings
# Processed 1515: MKEQLYTGLT... -> 173 embeddings
# Processed 1516: MTKPTSAGQA... -> 212 embeddings
# Processed 1517: GHALVARPAQ... -> 344 embeddings
# Processed 1518: GHMSELRILR... -> 202 embeddings
# Processed 1519: AYFVDRSKIE... -> 146 embeddings
# Processed 1520: SNAADLSLLK... -> 350 embeddings
# Processed 1521: AGHMKEIKEI... -> 98 embeddings
# Processed 1522: SNAAEFAPRS... -> 105 embeddings
# Processed 1523: APPVWYPGGQ... -> 29 embeddings
# Processed 1524: GSSGGPNVPE... -> 248 embeddings
# Processed 1525: GSTVPYTITV... -> 100 embeddings
# Processed 1526: MCIIKPMDDV... -> 175 embeddings
# Processed 1527: MGSSHHHHHH... -> 460 embeddings
# Processed 1528: MGSSHHHHHH... -> 319 embeddings
# Processed 1529: AFMSQMMQMY... -> 149 embeddings
# Processed 1530: QQARQNLQNL... -> 32 embeddings
# Processed 1531: GHMLYINSFL... -> 118 embeddings
# Processed 1532: GAAASIQTTV... -> 186 embeddings
# Processed 1533: GGVTDALSLA... -> 146 embeddings
# Processed 1534: SNAASQQVTA... -> 111 embeddings
# Processed 1535: ADLPAPDDTG... -> 351 embeddings
# Processed 1536: AGSSHHHHHH... -> 540 embeddings
# Processed 1537: MRGSHHHHHH... -> 264 embeddings
# Processed 1538: GHMSRRAPMF... -> 199 embeddings
# Processed 1539: GSHMAPFLRI... -> 128 embeddings
# Processed 1540: MYALTQGRIF... -> 384 embeddings
# Processed 1541: MQQSHQAGYA... -> 366 embeddings
# Processed 1542: ADNYAATRYP... -> 322 embeddings
# Processed 1543: MNYQMITTDD... -> 377 embeddings
# Processed 1544: MKIAILYREE... -> 260 embeddings
# Processed 1545: AKALEQPFDV... -> 176 embeddings
# Processed 1546: MSTAVQFRGG... -> 383 embeddings
# Processed 1547: ATHSPSFLQH... -> 343 embeddings
# Processed 1548: MGSSHHHHHH... -> 298 embeddings
# Processed 1549: MASMTGGQQM... -> 202 embeddings
# Processed 1550: GHASLHPVSI... -> 266 embeddings
# Processed 1551: ANLHFCQLRC... -> 29 embeddings
# Processed 1552: LPRRLHLEPA... -> 24 embeddings
# Processed 1553: EFMIIYRDLI... -> 176 embeddings
# Processed 1554: MAHHHHHHMS... -> 206 embeddings
# Processed 1555: MLGVIADDFT... -> 415 embeddings
# Processed 1556: EVNEKAPAQA... -> 98 embeddings
# Processed 1557: MSYEKEFLKD... -> 86 embeddings
# Processed 1558: MGSSHHHHHH... -> 280 embeddings
# Processed 1559: DYKLFITEGY... -> 209 embeddings
# Processed 1560: AEPKLSKDTI... -> 222 embeddings
# Processed 1561: MGSSHHHHHH... -> 165 embeddings
# Processed 1562: LKSESAEKTR... -> 114 embeddings
# Processed 1563: GPLGSMTTKQ... -> 326 embeddings
# Processed 1564: GSHMALKRIQ... -> 152 embeddings
# Processed 1565: HMVTLYTSPS... -> 134 embeddings
# Processed 1566: PEFAVTTEPA... -> 240 embeddings
# Processed 1567: MTAQLQSEST... -> 701 embeddings
# Processed 1568: MEVEKYDLTL... -> 782 embeddings
# Processed 1569: SNAAGLFDEV... -> 137 embeddings
# Processed 1570: SNAADISVID... -> 177 embeddings
# Processed 1571: MASYAELFDI... -> 169 embeddings
# Processed 1572: ADTCYNDVAL... -> 214 embeddings
# Processed 1573: EANAPGPVPG... -> 313 embeddings
# Processed 1574: SNAAETQDYA... -> 227 embeddings
# Processed 1575: MTSPSHASDR... -> 353 embeddings
# Processed 1576: AGSDKIHHHH... -> 236 embeddings
# Processed 1577: MALLKANKDL... -> 104 embeddings
# Processed 1578: APNTIRLHRV... -> 149 embeddings
# Processed 1579: GSHAAKHEQI... -> 130 embeddings
# Processed 1580: MAQKPVADAL... -> 277 embeddings
# Processed 1581: MNIAELYGKM... -> 284 embeddings
# Processed 1582: KEQLASMNAI... -> 252 embeddings
# Processed 1583: VMLTRQQKEL... -> 182 embeddings
# Processed 1584: GAMGSMKPYL... -> 394 embeddings
# Processed 1585: AILIGDSGST... -> 293 embeddings
# Processed 1586: EKKFSTEEEY... -> 142 embeddings
# Processed 1587: LETPGQYLVY... -> 115 embeddings
# Processed 1588: MTKIVSHRGA... -> 250 embeddings
# Processed 1589: MANYWLYKSE... -> 157 embeddings
# Processed 1590: AHHHHHHGSL... -> 152 embeddings
# Processed 1591: TGGCDVSARD... -> 124 embeddings
# Processed 1592: AKPATYNTEA... -> 405 embeddings
# Processed 1593: GAMVVSPAGA... -> 300 embeddings
# Processed 1594: AGSSHHHHHH... -> 262 embeddings
# Processed 1595: GSSHHHHHHS... -> 310 embeddings
# Processed 1596: MGSDKIHHHH... -> 342 embeddings
# Processed 1597: ASYKVNIPAG... -> 115 embeddings
# Processed 1598: GAMDPSQYAS... -> 440 embeddings
# Processed 1599: GSHMTNYKEK... -> 420 embeddings
# Processed 1600: AVSFIGSTEN... -> 178 embeddings
# Processed 1601: AASPRIGLTL... -> 185 embeddings
# Processed 1602: GHMFEKIRKI... -> 85 embeddings
# Processed 1603: AHHHHHHSSG... -> 270 embeddings
# Processed 1604: GHMTSRPSSD... -> 313 embeddings
# Processed 1605: AGSCMSITIN... -> 120 embeddings
# Processed 1606: SNAAEQFLDN... -> 120 embeddings
# Processed 1607: ACSHYQALKD... -> 229 embeddings
# Processed 1608: SALQDLLRTL... -> 49 embeddings
# Processed 1609: MIKSKGDVNI... -> 140 embeddings
# Processed 1610: SNAAKAIITV... -> 93 embeddings
# Processed 1611: EAEAEFNSIN... -> 505 embeddings
# Processed 1612: AVVLSVPAEV... -> 263 embeddings
# Processed 1613: AAHHHHHHAK... -> 166 embeddings
# Processed 1614: MASMEEPPLL... -> 530 embeddings
# Processed 1615: WKEPCRIELY... -> 82 embeddings
# Processed 1616: AGSDKIHHHH... -> 223 embeddings
# Processed 1617: AHHHHHHGSE... -> 135 embeddings
# Processed 1618: MGSSHHHHHH... -> 188 embeddings
# Processed 1619: AGSDKIHHHH... -> 317 embeddings
# Processed 1620: GSPLGQDVFL... -> 67 embeddings
# Processed 1621: ALGKLQDVVN... -> 79 embeddings
# Processed 1622: GMSGIKSLEL... -> 135 embeddings
# Processed 1623: SEPVTIVLSQ... -> 258 embeddings
# Processed 1624: MSVAGLKKQF... -> 258 embeddings
# Processed 1625: AGSSHHHHHH... -> 124 embeddings
# Processed 1626: AGSDKIHHHH... -> 138 embeddings
# Processed 1627: LHLDQTPSRQ... -> 405 embeddings
# Processed 1628: AGSDKIHHHH... -> 234 embeddings
# Processed 1629: MLDTNMKTQL... -> 204 embeddings
# Processed 1630: VLGSFYSPVK... -> 193 embeddings
# Processed 1631: GAMGPIITTQ... -> 84 embeddings
# Processed 1632: TTEENSKSEA... -> 127 embeddings
# Processed 1633: MKGGFTGGDE... -> 265 embeddings
# Processed 1634: MTQTTQSPAL... -> 141 embeddings
# Processed 1635: GSSHCRFYEN... -> 177 embeddings
# Processed 1636: MGSSHHHHHH... -> 148 embeddings
# Processed 1637: MSLQTPMQTV... -> 146 embeddings
# Processed 1638: SGTISSASFH... -> 310 embeddings
# Processed 1639: GSHMASEELQ... -> 52 embeddings
# Processed 1640: MVNILWELLH... -> 327 embeddings
# Processed 1641: AGSDKIHHHH... -> 260 embeddings
# Processed 1642: MHSTPKRVLL... -> 217 embeddings
# Processed 1643: AGSDKIHHHH... -> 357 embeddings
# Processed 1644: MSARISLFAV... -> 140 embeddings
# Processed 1645: SNDDKLYRAD... -> 195 embeddings
# Processed 1646: AINRRYELFK... -> 418 embeddings
# Processed 1647: MGGSFGKKGA... -> 264 embeddings
# Processed 1648: MEVKREHWAT... -> 521 embeddings
# Processed 1649: AAKNRALLLI... -> 169 embeddings
# Processed 1650: AGSDKIHHHH... -> 220 embeddings
# Processed 1651: MKKEVRKVRI... -> 1526 embeddings
# Processed 1652: MAEPGIDKLF... -> 101 embeddings
# Processed 1653: GPHMRTISYS... -> 88 embeddings
# Processed 1654: GSDASKLSSD... -> 224 embeddings
# Processed 1655: MVFEENSDEV... -> 252 embeddings
# Processed 1656: MIEQNEKASI... -> 272 embeddings
# Processed 1657: GSHMATMALS... -> 242 embeddings
# Processed 1658: MNKPLTPSTY... -> 115 embeddings
# Processed 1659: GSAPAVASVP... -> 146 embeddings
# Processed 1660: AGSDKIHHHH... -> 311 embeddings
# Processed 1661: MGHHHHHHKL... -> 271 embeddings
# Processed 1662: MGSSHHHHHH... -> 385 embeddings
# Processed 1663: MSEITIGVLS... -> 229 embeddings
# Processed 1664: HHHHHHMPVN... -> 184 embeddings
# Processed 1665: DYFTLYEAHL... -> 502 embeddings
# Processed 1666: SNAASTSLTI... -> 168 embeddings
# Processed 1667: MGLIDVAKSR... -> 236 embeddings
# Processed 1668: ACNLYRAEDK... -> 270 embeddings
# Processed 1669: MLSDYEEFLR... -> 376 embeddings
# Processed 1670: HMSSFSWDNC... -> 166 embeddings
# Processed 1671: TKFIGCIDLH... -> 262 embeddings
# Processed 1672: AKPVKPPRIN... -> 533 embeddings
# Processed 1673: TACTATQQTA... -> 100 embeddings
# Processed 1674: AGSDKIHHHH... -> 161 embeddings
# Processed 1675: AGSDKIHHHH... -> 333 embeddings
# Processed 1676: SIEKIWAREI... -> 441 embeddings
# Processed 1677: GAMERVLKVF... -> 377 embeddings
# Processed 1678: GPGSMAEEIR... -> 209 embeddings
# Processed 1679: AGSDKIHHHH... -> 375 embeddings
# Processed 1680: MHHHHHHMNP... -> 127 embeddings
# Processed 1681: PLGSQYFLKV... -> 180 embeddings
# Processed 1682: AGSDKIHHHH... -> 257 embeddings
# Processed 1683: MPFSISGRKG... -> 157 embeddings
# Processed 1684: MASSMRSLFS... -> 294 embeddings
# Processed 1685: AHMGIQRPTS... -> 201 embeddings
# Processed 1686: MEGGSITPGE... -> 262 embeddings
# Processed 1687: AKSTEKKELS... -> 159 embeddings
# Processed 1688: KRIVACDDPD... -> 436 embeddings
# Processed 1689: MARQVFDDKL... -> 149 embeddings
# Processed 1690: DPLLPGYSFN... -> 166 embeddings
# Processed 1691: GEFSTREGEI... -> 253 embeddings
# Processed 1692: AGGPGSRARA... -> 115 embeddings
# Processed 1693: RENFPGVSWD... -> 338 embeddings
# Processed 1694: ATEAELKLIK... -> 182 embeddings
# Processed 1695: SNAALILSTE... -> 141 embeddings
# Processed 1696: AHHHHHHSSG... -> 226 embeddings
# Processed 1697: MFKIGSVLKQ... -> 319 embeddings
# Processed 1698: ARGSRSGHGN... -> 266 embeddings
# Processed 1699: AISSIRLDLF... -> 272 embeddings
# Processed 1700: MGHHHHHHHH... -> 469 embeddings
# Processed 1701: AELHLESRGG... -> 136 embeddings
# Processed 1702: SRIVVHTQTL... -> 78 embeddings
# Processed 1703: MESKAKTTVT... -> 431 embeddings
# Processed 1704: MAHHHHHHMS... -> 291 embeddings
# Processed 1705: MKTPTFGKRE... -> 150 embeddings
# Processed 1706: MSRSQLTILT... -> 157 embeddings
# Processed 1707: EILDLTQTLI... -> 188 embeddings
# Processed 1708: MARKEAKMLY... -> 208 embeddings
# Processed 1709: MAKIIWTRTD... -> 740 embeddings
# Processed 1710: GHMNIESTLN... -> 566 embeddings
# Processed 1711: AARPNFRYTH... -> 106 embeddings
# Processed 1712: MKKHHHHHHQ... -> 201 embeddings
# Processed 1713: MGSDKIHHHH... -> 140 embeddings
# Processed 1714: MGSSHHHHHH... -> 256 embeddings
# Processed 1715: GSSMDSRLQR... -> 100 embeddings
# Processed 1716: AKQVKAAFEA... -> 317 embeddings
# Processed 1717: AAKFVIRPAT... -> 173 embeddings
# Processed 1718: ELCDDDPPEI... -> 219 embeddings
# Processed 1719: AGSSHHHHHH... -> 345 embeddings
# Processed 1720: MIKLMVGSFA... -> 387 embeddings
# Processed 1721: SNAAKHAEKF... -> 325 embeddings
# Processed 1722: SPSPLNPGTN... -> 213 embeddings
# Processed 1723: IRPYMKALIY... -> 79 embeddings
# Processed 1724: GAIEKVYEFK... -> 119 embeddings
# Processed 1725: AVCPTGLFSN... -> 73 embeddings
# Processed 1726: MTKKVGIVDT... -> 158 embeddings
# Processed 1727: MNRRIQLVEE... -> 149 embeddings
# Processed 1728: MKQPYAVVAS... -> 54 embeddings
# Processed 1729: ENIIRIKDDN... -> 64 embeddings
# Processed 1730: MSISKDSRIA... -> 426 embeddings
# Processed 1731: VKTPGTRYVT... -> 87 embeddings
# Processed 1732: GSHMLCAISG... -> 63 embeddings
# Processed 1733: AGSSHHHHHH... -> 223 embeddings
# Processed 1734: MSDSKEVPSL... -> 197 embeddings
# Processed 1735: MTFQASGTTG... -> 167 embeddings
# Processed 1736: KSKKAVWHKL... -> 32 embeddings
# Processed 1737: ARTLAIEPLT... -> 177 embeddings
# Processed 1738: AKKLYIITGP... -> 191 embeddings
# Processed 1739: VEGAVKTEPV... -> 451 embeddings
# Processed 1740: SSLDDKPQFP... -> 402 embeddings
# Processed 1741: VAHFTFQPDP... -> 344 embeddings
# Processed 1742: GSHNGIDCSF... -> 202 embeddings
# Processed 1743: MTEMVISPAE... -> 98 embeddings
# Processed 1744: GSGAPPTDLQ... -> 211 embeddings
# Processed 1745: MTQTQPVTPT... -> 604 embeddings
# Processed 1746: QESSGNKIHF... -> 549 embeddings
# Processed 1747: GSHPFNSEPP... -> 426 embeddings
# Processed 1748: GSMADEALFL... -> 162 embeddings
# Processed 1749: MTTKEFEDTW... -> 347 embeddings
# Processed 1750: MDITVREHDF... -> 455 embeddings
# Processed 1751: GAMVSGQIMH... -> 99 embeddings
# Processed 1752: EQWQTLYEAI... -> 130 embeddings
# Processed 1753: MDPVVLSYMD... -> 214 embeddings
# Processed 1754: MMDYLITQNG... -> 158 embeddings
# Processed 1755: MKKNAKQIVH... -> 105 embeddings
# Processed 1756: MENLSDVFDI... -> 240 embeddings
# Processed 1757: MKTVVFAYHD... -> 307 embeddings
# Processed 1758: GSHMQQWVDC... -> 188 embeddings
# Processed 1759: MNDYSRQNFQ... -> 238 embeddings
# Processed 1760: MSYQNLVSEA... -> 449 embeddings
# Processed 1761: MMINTQEDKL... -> 196 embeddings
# Processed 1762: AASNQTVYQF... -> 138 embeddings
# Processed 1763: MSNTKTASTG... -> 200 embeddings
# Processed 1764: MSLVVFPFKH... -> 399 embeddings
# Processed 1765: MEIPPTNYPA... -> 224 embeddings
# Processed 1766: MSIFPTRDSR... -> 316 embeddings
# Processed 1767: MHHHHHHGST... -> 334 embeddings
# Processed 1768: DSRGCARWCP... -> 145 embeddings
# Processed 1769: MSTAEFAQLL... -> 863 embeddings
# Processed 1770: MAHHHHHHMA... -> 499 embeddings
# Processed 1771: MTNESILESY... -> 258 embeddings
# Processed 1772: GAMGQTTFTE... -> 135 embeddings
# Processed 1773: MEACPHIRYA... -> 280 embeddings
# Processed 1774: SSVQTAATSW... -> 92 embeddings
# Processed 1775: GSALILTRRV... -> 65 embeddings
# Processed 1776: GGAIKPDMKI... -> 222 embeddings
# Processed 1777: FCLTLRRRYT... -> 256 embeddings
# Processed 1778: GSHMSNAKTK... -> 204 embeddings
# Processed 1779: MVSSKLATPL... -> 461 embeddings
# Processed 1780: SHAQSRELKT... -> 536 embeddings
# Processed 1781: SVVVISQALP... -> 403 embeddings
# Processed 1782: AQLKRVAEAK... -> 198 embeddings
# Processed 1783: APPNLWAAQR... -> 29 embeddings
# Processed 1784: MHHHHHHSSG... -> 364 embeddings
# Processed 1785: MRGSHHHHHH... -> 250 embeddings
# Processed 1786: ARTLFFIPSA... -> 205 embeddings
# Processed 1787: SGLVPRGSHM... -> 218 embeddings
# Processed 1788: MNFFSLHPNV... -> 360 embeddings
# Processed 1789: ETEAIDNGAL... -> 340 embeddings
# Processed 1790: MASNRGQLNH... -> 294 embeddings
# Processed 1791: ARTFESVADL... -> 153 embeddings
# Processed 1792: MTKKSTKSEA... -> 209 embeddings
# Processed 1793: PVLDQLTDPP... -> 287 embeddings
# Processed 1794: MHHHHHHMGL... -> 249 embeddings
# Processed 1795: GSHMASGDAT... -> 104 embeddings
# Processed 1796: GAMGTTNGTD... -> 381 embeddings
# Processed 1797: KSLRVSSLNK... -> 26 embeddings
# Processed 1798: GSSEEESFFV... -> 119 embeddings
# Processed 1799: AHHHHHHSSG... -> 113 embeddings
# Processed 1800: MKHHHHHHPM... -> 471 embeddings
# Processed 1801: SPCDTNWRYY... -> 124 embeddings
# Processed 1802: MSLKSERRGI... -> 76 embeddings
# Processed 1803: SMQAARLAKA... -> 171 embeddings
# Processed 1804: MSVTVPNDDW... -> 87 embeddings
# Processed 1805: GSMAASLVGK... -> 198 embeddings
# Processed 1806: MAHHHHHHME... -> 147 embeddings
# Processed 1807: MPKPYVAINM... -> 320 embeddings
# Processed 1808: MSQAEFEKAA... -> 89 embeddings
# Processed 1809: MAAHQLSDFQ... -> 193 embeddings
# Processed 1810: GSASPAVAEL... -> 101 embeddings
# Processed 1811: RVQSGKIDCG... -> 103 embeddings
# Processed 1812: MKAIIVKPPN... -> 368 embeddings
# Processed 1813: MSAKLISVTK... -> 219 embeddings
# Processed 1814: ARYLELAQLY... -> 563 embeddings
# Processed 1815: AEETCFDKYT... -> 92 embeddings
# Processed 1816: PQFMAAIYGG... -> 349 embeddings
# Processed 1817: GSHMKDVQTE... -> 311 embeddings
# Processed 1818: GAMGPVDEQW... -> 172 embeddings
# Processed 1819: MENFEIWVEK... -> 228 embeddings
# Processed 1820: MKTENAKTNQ... -> 155 embeddings
# Processed 1821: ATFGRATHVV... -> 277 embeddings
# Processed 1822: MSAVALPRVS... -> 457 embeddings
# Processed 1823: MPIKETDKEV... -> 299 embeddings
# Processed 1824: GAMGSGDTQL... -> 129 embeddings
# Processed 1825: AGSSHHHHHH... -> 524 embeddings
# Processed 1826: MASTRGSGRP... -> 95 embeddings
# Processed 1827: GGVMSLLCVG... -> 133 embeddings
# Processed 1828: GEEEKKRTAR... -> 129 embeddings
# Processed 1829: AQEKPQEPKV... -> 190 embeddings
# Processed 1830: MWITQEITPY... -> 264 embeddings
# Processed 1831: ASITKTELDG... -> 308 embeddings
# Processed 1832: GSQKSVDIVF... -> 139 embeddings
# Processed 1833: MGTEPPENCQ... -> 106 embeddings
# Processed 1834: QGRYTTDDGY... -> 57 embeddings
# Processed 1835: AVWLNGEPRP... -> 66 embeddings
# Processed 1836: MAAYQVLIVG... -> 234 embeddings
# Processed 1837: ALQYPELPLE... -> 190 embeddings
# Processed 1838: MSLTLADKVV... -> 193 embeddings
# Processed 1839: MVTAFILMVT... -> 85 embeddings
# Processed 1840: TLPKRVKIVE... -> 300 embeddings
# Processed 1841: GSSGSSGDES... -> 196 embeddings
# Processed 1842: AGSSHHHHHH... -> 139 embeddings
# Processed 1843: MPAAAPGKNF... -> 239 embeddings
# Processed 1844: AVPDWEEVLG... -> 96 embeddings
# Processed 1845: ARGSHHHHHH... -> 258 embeddings
# Processed 1846: MSGDYRITLE... -> 146 embeddings
# Processed 1847: AGSSHHHHHH... -> 219 embeddings
# Processed 1848: APKFDVSKSD... -> 350 embeddings
# Processed 1849: GSSGSSGAVT... -> 97 embeddings
# Processed 1850: MAALTRNPQF... -> 559 embeddings
# Processed 1851: GSSGSSGEKI... -> 127 embeddings
# Processed 1852: STVVAADVSQ... -> 142 embeddings
# Processed 1853: AEGFPVRVRV... -> 135 embeddings
# Processed 1854: GSSHHHHHHS... -> 121 embeddings
# Processed 1855: MEALRLGFSP... -> 274 embeddings
# Processed 1856: MVSGEVRTKK... -> 82 embeddings
# Processed 1857: MMRKLKTLPP... -> 122 embeddings
# Processed 1858: MVPVRMAVIA... -> 111 embeddings
# Processed 1859: MSNYVIQADQ... -> 312 embeddings
# Processed 1860: MRYIAGIDIG... -> 612 embeddings
# Processed 1861: MDVNNSKPND... -> 500 embeddings
# Processed 1862: AGHAEAVIEK... -> 255 embeddings
# Processed 1863: MENMENDENI... -> 550 embeddings
# Processed 1864: AEQRSAETRI... -> 151 embeddings
# Processed 1865: AIINLLRELE... -> 251 embeddings
# Processed 1866: HKCDITLQEI... -> 131 embeddings
# Processed 1867: AKYGIVLFPS... -> 173 embeddings
# Processed 1868: MRFRPFTEED... -> 143 embeddings
# Processed 1869: MEETRPIDGL... -> 146 embeddings
# Processed 1870: MEKVFYVTTP... -> 502 embeddings
# Processed 1871: MKKSLGARTL... -> 192 embeddings
# Processed 1872: MGPQDNSLVI... -> 605 embeddings
# Processed 1873: KTPLVNESLK... -> 84 embeddings
# Processed 1874: AAARDPEATK... -> 204 embeddings
# Processed 1875: VSRDELAEAI... -> 44 embeddings
# Processed 1876: MPVAHVALPV... -> 107 embeddings
# Processed 1877: ASFGGKSASE... -> 164 embeddings
# Processed 1878: TALPAFNVNP... -> 320 embeddings
# Processed 1879: MDERIQALRK... -> 92 embeddings
# Processed 1880: AKKTLPKTEA... -> 106 embeddings
# Processed 1881: MSMEEEEFDI... -> 255 embeddings
# Processed 1882: GSSGSSGGYF... -> 66 embeddings
# Processed 1883: MKDHLIHNVH... -> 463 embeddings
# Processed 1884: AVNPAERLAE... -> 92 embeddings
# Processed 1885: ALAVGIVGLP... -> 370 embeddings
# Processed 1886: MLVGLIGYGA... -> 238 embeddings
# Processed 1887: MEIEVKFRVN... -> 167 embeddings
# Processed 1888: MGSSHHHHHH... -> 218 embeddings
# Processed 1889: MVEVEHWNTL... -> 129 embeddings
# Processed 1890: PDPMKNTCKL... -> 259 embeddings
# Processed 1891: MSSLLLFNDK... -> 285 embeddings
# Processed 1892: EVSTTQNDTL... -> 308 embeddings
# Processed 1893: GRSEKQKQVI... -> 389 embeddings
# Processed 1894: LDGVLVPESG... -> 335 embeddings
# Processed 1895: MNSMELLIIK... -> 192 embeddings
# Processed 1896: MTSRVDPANP... -> 367 embeddings
# Processed 1897: MANVDEAILK... -> 394 embeddings
# Processed 1898: MIKVKSPGRV... -> 352 embeddings
# Processed 1899: MAMSQQDLPT... -> 335 embeddings
# Processed 1900: AARWDPGAEQ... -> 197 embeddings
# Processed 1901: MATGHTDPQR... -> 195 embeddings
# Processed 1902: DSRFGAKSIS... -> 454 embeddings
# Processed 1903: DRWGSELPAQ... -> 426 embeddings
# Processed 1904: MGHHHHHHMP... -> 237 embeddings
# Processed 1905: DTPANCTYLD... -> 121 embeddings
# Processed 1906: MSIEQTLSQY... -> 546 embeddings
# Processed 1907: MVSTLKRDEA... -> 409 embeddings
# Processed 1908: SGISLDNSYK... -> 148 embeddings
# Processed 1909: ASGVDDDMAC... -> 105 embeddings
# Processed 1910: AAGYLNNIAL... -> 82 embeddings
# Processed 1911: MNGAELIIQE... -> 200 embeddings
# Processed 1912: VEKLTADAEL... -> 32 embeddings
# Processed 1913: GSPEFMELEI... -> 188 embeddings
# Processed 1914: MDYMERPKLG... -> 126 embeddings
# Processed 1915: MDNVLLSGQT... -> 117 embeddings
# Processed 1916: MKIKEIKKVT... -> 286 embeddings
# Processed 1917: GEAAYQAMLA... -> 23 embeddings
# Processed 1918: MKIEDIYQFF... -> 117 embeddings
# Processed 1919: GPNANPIPEH... -> 313 embeddings
# Processed 1920: MRRAGYLHLY... -> 133 embeddings
# Processed 1921: MEEAVLTGVA... -> 180 embeddings
# Processed 1922: MELIEVQEGK... -> 380 embeddings
# Processed 1923: MIREKALEFH... -> 441 embeddings
# Processed 1924: GSSGSSGAAN... -> 182 embeddings
# Processed 1925: MSVCHKHSVI... -> 278 embeddings
# Processed 1926: GSSGSSGATP... -> 168 embeddings
# Processed 1927: ASSDAISLRA... -> 152 embeddings
# Processed 1928: MLGLKTSIIG... -> 237 embeddings
# Processed 1929: GSSGSSGMTA... -> 192 embeddings
# Processed 1930: MRLVEIGRFG... -> 164 embeddings
# Processed 1931: MAYGKAHLEA... -> 97 embeddings
# Processed 1932: GAHMNDIKQL... -> 299 embeddings
# Processed 1933: MGNFIITERK... -> 59 embeddings
# Processed 1934: MNNQGSIISV... -> 261 embeddings
# Processed 1935: MHDLRISLVQ... -> 268 embeddings
# Processed 1936: MPKYAPHVYT... -> 103 embeddings
# Processed 1937: GIQPVISAQE... -> 105 embeddings
# Processed 1938: AASLPILTVL... -> 456 embeddings
# Processed 1939: MNREEMTLLG... -> 107 embeddings
# Processed 1940: PKWQAVRAEY... -> 179 embeddings
# Processed 1941: MMIIVGVDAG... -> 301 embeddings
# Processed 1942: ELKIGDRVLV... -> 92 embeddings
# Processed 1943: SNSLHWPTSL... -> 257 embeddings
# Processed 1944: MSSERTFLPN... -> 148 embeddings
# Processed 1945: GSRSEPAKVV... -> 521 embeddings
# Processed 1946: MKKSALEKLL... -> 302 embeddings
# Processed 1947: EAQKQYWVCN... -> 146 embeddings
# Processed 1948: TVKSGLILQS... -> 349 embeddings
# Processed 1949: MKTLIEIKQT... -> 327 embeddings
# Processed 1950: MKTIHVSVVT... -> 135 embeddings
# Processed 1951: MMCLKLNLLD... -> 316 embeddings
# Processed 1952: KSVLEDNLPF... -> 210 embeddings
# Processed 1953: AEKDLLDKLG... -> 71 embeddings
# Processed 1954: MFKRETKDFI... -> 373 embeddings
# Processed 1955: DKKAYFYHSS... -> 123 embeddings
# Processed 1956: KKHVVCQSCD... -> 729 embeddings
# Processed 1957: MRTFTWRKGS... -> 203 embeddings
# Processed 1958: MEVKEVELEL... -> 134 embeddings
# Processed 1959: MWDTSKDYRL... -> 243 embeddings
# Processed 1960: MTKNKMEAKI... -> 342 embeddings
# Processed 1961: MDAAEVEFLA... -> 187 embeddings
# Processed 1962: MFCEKAMELI... -> 151 embeddings
# Processed 1963: MTEEVDFLGQ... -> 225 embeddings
# Processed 1964: MVIASVEDGG... -> 901 embeddings
# Processed 1965: QFSDMRISIN... -> 92 embeddings
# Processed 1966: MRLTEEEVQA... -> 103 embeddings
# Processed 1967: MQAVRLFQGY... -> 108 embeddings
# Processed 1968: MAIVPFKRDP... -> 464 embeddings
# Processed 1969: MKEAFKEALA... -> 151 embeddings
# Processed 1970: TVTKTIETHT... -> 172 embeddings
# Processed 1971: GSMENTDVFL... -> 269 embeddings
# Processed 1972: MELQEVLHMN... -> 386 embeddings
# Processed 1973: GSSGSSGQFE... -> 303 embeddings
# Processed 1974: MPLVGFMKEK... -> 94 embeddings
# Processed 1975: MHVFYSEERR... -> 231 embeddings
# Processed 1976: AGTKERILEV... -> 181 embeddings
# Processed 1977: DEGPLMMNAF... -> 145 embeddings
# Processed 1978: MIIGYFDGLC... -> 151 embeddings
# Processed 1979: APAIFTHEGK... -> 128 embeddings
# Processed 1980: AACHELSALR... -> 122 embeddings
# Processed 1981: HMDIRPRLRI... -> 242 embeddings
# Processed 1982: GSSGSSGETE... -> 162 embeddings
# Processed 1983: GSHMMKVEKE... -> 141 embeddings
# Processed 1984: AQANSEKFFK... -> 209 embeddings
# Processed 1985: MDAVKKAILG... -> 331 embeddings
# Processed 1986: ADGRSTRYWD... -> 212 embeddings
# Processed 1987: MATFLGLSSK... -> 629 embeddings
# Processed 1988: MYRMDKYTIG... -> 230 embeddings
# Processed 1989: LAMPAAERLM... -> 42 embeddings
# Processed 1990: GGDNSVFDIF... -> 211 embeddings
# Processed 1991: ADVSAAVGAT... -> 152 embeddings
# Processed 1992: GHHHHHHHHH... -> 334 embeddings
# Processed 1993: AVNFKDKSAP... -> 117 embeddings
# Processed 1994: GASEENKIGT... -> 250 embeddings
# Processed 1995: TDPDPLQDFC... -> 203 embeddings
# Processed 1996: FDRDRLFSVV... -> 258 embeddings
# Processed 1997: AGSDAIHHHH... -> 173 embeddings
# Processed 1998: AGSDKIHHHH... -> 156 embeddings
# Processed 1999: AGSDKIHHHH... -> 252 embeddings
# Processed 2000: AGSDKIHHHH... -> 130 embeddings
# Processed sequences 1001 to 2000. Embeddings saved to /content/drive/MyDrive/PSSP big/train_embeddings_2

# %%
import pandas as pd
import json

# Load the CSV file containing embeddings
csv_file = "/content/drive/MyDrive/PSSP big/train_embeddings_2"  # Update with the correct file
df = pd.read_csv(csv_file)

# Iterate over the first 5 sequences
for i in range(min(5, len(df))):
    sequence = df.loc[i, "sequence"]
    embeddings = json.loads(df.loc[i, "embedding"])  # Convert from JSON string to list

    print(f"Sequence {i+1}: {sequence[:10]}...")  # Print first 10 AAs for reference
    print("First 5 amino acid embeddings:")

    # Print embeddings for first 5 amino acids
    for j in range(min(5, len(embeddings))):
        print(f"AA {j+1}: {embeddings[j][:5]}")  # Print first 5 dimensions for readability

    print("-" * 50)  # Separator for clarity
# Out:
# Sequence 1: MAASNATYNN...
# First 5 amino acid embeddings:
# AA 1: [0.16351790726184845, 0.026101328432559967, 0.08993391692638397, -0.2651503086090088, 0.2581440508365631]
# AA 2: [0.08048053830862045, 0.08980249613523483, 0.040511604398489, -0.1695208102464676, 0.14786012470722198]
# AA 3: [0.10991034656763077, 0.04478240758180618, 0.029447514563798904, -0.09592229127883911, 0.07564140856266022]
# AA 4: [0.007083553355187178, 0.07397487759590149, 0.017930403351783752, -0.11953765898942947, 0.06586409360170364]
# AA 5: [-0.01959274895489216, -0.0016199809033423662, 0.08816464990377426, -0.061735354363918304, 0.08922812342643738]
# --------------------------------------------------
# Sequence 2: MSITLSDSAA...
# First 5 amino acid embeddings:
# AA 1: [0.10945986956357956, 0.019381141290068626, 0.04453824833035469, -0.325766384601593, 0.2756304144859314]
# AA 2: [0.10565010458230972, 0.07076577097177505, 0.08626673370599747, -0.03645419701933861, 0.34749260544776917]
# AA 3: [0.09130249917507172, 0.13519445061683655, 0.022198090329766273, 0.03512934595346451, 0.15541712939739227]
# AA 4: [0.049136944115161896, 0.28419381380081177, 0.025760795921087265, -0.09361989051103592, -0.05257062986493111]
# AA 5: [-0.11967770755290985, 0.1386173665523529, -0.08461043983697891, -0.0021551118697971106, 0.24694372713565826]
# --------------------------------------------------
# Sequence 3: MEHICGTSRI...
# First 5 amino acid embeddings:
# AA 1: [0.09819715470075607, -0.004178182687610388, 0.05129034444689751, -0.22778135538101196, 0.18236994743347168]
# AA 2: [0.30206209421157837, 0.08146899193525314, 0.08802024275064468, -0.09585744887590408, 0.3828974962234497]
# AA 3: [0.21406583487987518, 0.15152812004089355, -0.03697681799530983, 0.029538070783019066, 0.1657959669828415]
# AA 4: [0.09907326102256775, 0.10184699296951294, -0.1093440130352974, 0.050259049981832504, 0.32181692123413086]
# AA 5: [0.24421493709087372, 0.1317024827003479, -0.12296029180288315, 0.012084005400538445, 0.21208809316158295]
# --------------------------------------------------
# Sequence 4: MSVFDSKFKG...
# First 5 amino acid embeddings:
# AA 1: [0.1454523801803589, 0.01819164678454399, 0.08356421440839767, -0.27207913994789124, 0.2639920711517334]
# AA 2: [0.12621887028217316, 0.1135869026184082, -0.06095463037490845, -0.11906225234270096, 0.2527499794960022]
# AA 3: [-0.005973049905151129, -0.03307624161243439, 0.1541810780763626, -0.03880563750863075, 0.12914764881134033]
# AA 4: [-0.10434281080961227, -0.06923656165599823, 0.13320188224315643, 0.031840547919273376, 0.10364311933517456]
# AA 5: [-0.05581505596637726, -0.05919332429766655, 0.05614520609378815, -0.008106417953968048, 0.12932029366493225]
# --------------------------------------------------
# Sequence 5: SDAATTFLQR...
# First 5 amino acid embeddings:
# AA 1: [0.0423160083591938, -0.012330199591815472, 0.08913683891296387, -0.10983429849147797, 0.21140241622924805]
# AA 2: [0.20786835253238678, 0.0841173380613327, 0.1915237158536911, -0.23683936893939972, 0.28524285554885864]
# AA 3: [-0.05017416924238205, -0.1907946914434433, 0.0239239614456892, 0.11963670700788498, 0.06492017954587936]
# AA 4: [-0.0418219156563282, 0.03632624074816704, -0.0856417566537857, 0.142898827791214, 0.1388915330171585]
# AA 5: [0.09865987300872803, 0.03822655975818634, -0.09375468641519547, 0.028639480471611023, -0.03222743049263954]
# --------------------------------------------------
